# %% [markdown]
# <h1>5.4 SVM<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#5.4.1-最大间隔超平面" data-toc-modified-id="5.4.1-最大间隔超平面-1">5.4.1 最大间隔超平面</a></span></li><li><span><a href="#5.4.2-支持向量" data-toc-modified-id="5.4.2-支持向量-2">5.4.2 支持向量</a></span></li><li><span><a href="#5.4.4-软间隔最大化" data-toc-modified-id="5.4.4-软间隔最大化-3">5.4.4 软间隔最大化</a></span></li><li><span><a href="#5.4.5-核函数" data-toc-modified-id="5.4.5-核函数-4">5.4.5 核函数</a></span></li><li><span><a href="#5.4.6-SVM算法的应用" data-toc-modified-id="5.4.6-SVM算法的应用-5">5.4.6 SVM算法的应用</a></span></li></ul></div>

# %% [markdown]
# # 5.4.1 最大间隔超平面

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from matplotlib.colors import ListedColormap
from sklearn.metrics import roc_auc_score

# %%
plt.figure(figsize = (8,6))
x = np.linspace(-10, 10, 200)
y1 = x * 0.5 + 1
y2 = x * 0.3 + 2
y3 = x * 0.2 + 0.5
plt.plot(x,y1,color = 'b')
plt.plot(x,y2,color = 'b')
plt.plot(x,y3,color = 'b')
plt.scatter([1,-1,0.5,-1,5],[-1.5,-2.5,-1,-2,1.3],marker ='s')
plt.scatter([1,2,1,1.5,-1,-5],[4,8,5,6,3,2],marker='o')
plt.xticks([])

plt.yticks([])
plt.show()

# %%
plt.figure(figsize = (8,6))
x = np.linspace(-10, 10, 200)
y1 = x * 0.5 + 1
y2 = x * 0.5 + 3.5
y3 = x * 0.5 - 1.2
plt.scatter([1,-1,0.5,-1,3],[3.5,2.5,-1,-2,1.3],marker ='s')
plt.scatter([1,2,1,1.5,-1,-5],[4,1,5,6,3,2],marker ='o')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # 5.4.2 支持向量

# %%
plt.figure(figsize = (10,10))
x = np.linspace(-10, 10, 200)
y1 = x * 0.5 + 1
y2 = x * 0.5 + 3.5
y3 = x * 0.5 - 1.2
plt.plot(x,y1,color = 'r')
plt.plot(x,y2,'b--')
plt.plot(x,y3, 'b--')
plt.scatter([1,-1,0.5,-1,5],[-1.5,-2.5,-1,-2,1.3],color = 'b',marker ='s')
plt.scatter([1,2,1,1.5,-1,-5],[4,8,5,6,3,2],color = 'r',marker ='o')
plt.scatter([0.5,5],[-1,1.3],marker='s',linewidths = 5,color = 'b',label ='a')
plt.scatter([1,-1],[4,3],marker='o',linewidths = 5,color = 'r')
plt.text(0.1,-0.8,'A')
plt.text(4.5,1.5,'B')
plt.text(0.7,3.5,'C')
plt.text(-1,2.5,'D')
plt.text(-10,-4,'wx+b=0',fontsize = 15)
plt.text(-10,-1.5,'wx+b=1',fontsize = 15)
plt.text(-10,-6,'wx+b=-1',fontsize = 15)
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # 5.4.4 软间隔最大化

# %%
plt.figure(figsize = (8,6))
x = np.linspace(-10, 10, 200)
y1 = x * 0.5 + 1
y2 = x * 0.3 + 2
# y3 = x * 0.2 + 0.5
plt.plot(x,y1,color = 'b')
# plt.plot(x,y2,color = 'b')
# plt.plot(x,y3,color = 'b')
plt.scatter([1,-1,0.5,-1,5,4],[-1.5,-2.5,-1,-2,1.3,6],color = 'b',marker ='s')
plt.scatter([1,2,1,1.5,-1,-5,1],[4,8,5,6,3,2,-1],color = 'r',marker ='o')
plt.xticks([])

plt.yticks([])
plt.show()

# %% [markdown]
# # 5.4.5 核函数

# %%
# 核函数
fig, ax = plt.subplots(1, 1,figsize = (8,6))
# plt.figure(figsize = (8,6))
x = np.linspace(-10, 10, 200)
y1 = x * 0 + 3
plt.plot(x,y1,color = 'b')
plt.scatter([0,1,-2,7],[3,3,3,3],color = 'g',linewidths= 5,marker ='s')
plt.scatter([-1,5,-3],[3,3,3],color = 'r',linewidths= 5,marker ='o')
plt.xticks([])
plt.yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.show()

# %%
fig, ax = plt.subplots(1, 1,figsize = (8,6))
# plt.figure(figsize = (8,6))
x = np.linspace(-10, 10, 200)
y1 = x * 0 + 4
plt.plot(x,y1,color = 'b')
plt.scatter([0,1,-2,7],[3,3,3,3],color = 'g',linewidths= 5,marker ='s')
plt.scatter([-1,5,-3],[5,5,5],color = 'r',linewidths= 5,marker ='o')
plt.ylim(2.5,6.5)
plt.xticks([])
plt.yticks([])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.show()

# %% [markdown]
# # 5.4.6 SVM算法的应用

# %%
# 画出决策边界
def plot_decision_boundary(model, axis):

    x0, x1 = np.meshgrid(
        np.linspace(axis[0], axis[1], int((axis[1] - axis[0])*100)).reshape(1, -1),
        np.linspace(axis[2], axis[3], int((axis[3] - axis[2])*100)).reshape(1, -1)
    )
    X_new = np.c_[x0.ravel(), x1.ravel()]

    y_predict = model.predict(X_new)
    zz = y_predict.reshape(x0.shape)

    custom_cmap = ListedColormap(['#EF9A9A', '#FFF59D', '#90CAF9'])
    plt.contourf(x0, x1, zz, linewidth=5, cmap=custom_cmap)

# %%
# 使用鸢尾花数据集
iris = datasets.load_iris()

X = iris.data
y = iris.target

# 只使用两个特征和两个种类
X = X[y < 2, 2:4]
y = y[y < 2]
# 划分数据集
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=2019)

# hard margin SVM
svc = LinearSVC(C=1)
svc.fit(x_train, y_train)
# Out:
# LinearSVC(C=1)

# %%
prediction = svc.predict(x_test)
auc=roc_auc_score(y_test, prediction)
print(auc)
# Out:
# 1.0

# %%
plot_decision_boundary(svc,axis=[0,6,-1,4])
plt.scatter(x_test[y_test==0,0],x_test[y_test==0,1])    
plt.scatter(x_test[y_test==1,0],x_test[y_test==1,1])  
plt.show()#C=1e9,如下右图是c=0.1时的图像
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: UserWarning: The following kwargs were not used by contour: 'linewidth'
